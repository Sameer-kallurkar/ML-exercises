# %%
import pandas as pd
import numbers as np
import matplotlib.pyplot as plt
from sklearn import linear_model, model_selection
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/Users/sameerkallurkar/PycharmProjects/ML_exec/mini project10 (random forest)/Mobile-Price-Prediction-cleaned_data.csv')
df.head()
# Out:
#    Ratings  RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0      4.3  4.0  128.0         6.00           48       13.0           4000
# 1      3.4  6.0   64.0         4.50           48       12.0           4000
# 2      4.3  4.0    4.0         4.50           64       16.0           4000
# 3      4.4  6.0   64.0         6.40           48       15.0           3800
# 4      4.5  6.0  128.0         6.18           35       15.0           3800
#
#    Price
# 0  24999
# 1  15999
# 2  15000
# 3  18999
# 4  18999

# %%
plt.scatter(df['Ratings'], df['Price'])

# %%
plt.scatter(df['Battery_Power'], df['Price'])

# %%
plt.scatter(df['ROM'], df['Price'])

# %%
plt.scatter(df['RAM'], df['Price'])

# %%
x = df.drop('Price', axis='columns')
y = df['Price']

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x , y, test_size=0.2, random_state=10)

# %%
model1 = linear_model.LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model1.score(x_test, y_test)
# Out:
# 0.39493679516283087

# %%
model_RFC = RandomForestClassifier(n_estimators=80)

# %%
model_RFC.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=80)

# %%
model_RFC.score(x_test, y_test)
# Out:
# 0.5679012345679012
