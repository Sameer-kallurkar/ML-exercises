# %%
import pandas as pd
import numbers as np
import matplotlib.pyplot as plt
from sklearn import linear_model, model_selection

# %%
df = pd.read_csv('/Users/sameerkallurkar/PycharmProjects/ML_exec/mini project 1 (linear regression)/Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
plt.scatter(df['GRE Score'], df['Chance of Admit'])

# %%
plt.scatter(df['TOEFL Score'], df['Chance of Admit'])

# %%
plt.scatter(df['CGPA'], df['Chance of Admit'])

# %%
x = df.drop('Chance of Admit', axis='columns')
y = df['Chance of Admit']

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x , y, test_size=0.2)

# %%
model = linear_model.LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([0.91831567, 0.67688427, 0.81249202, 0.61660786, 0.74880824,
#        0.83699228, 0.65356735, 0.64236547, 0.79708464, 0.662039  ,
#        0.62237648, 0.83473974, 0.70178695, 0.71313122, 0.80862871,
#        0.63645801, 0.73037744, 0.69968881, 0.76642913, 0.96144938,
#        0.59482292, 0.57831689, 0.88332165, 0.72651646, 0.49415416,
#        0.75315142, 0.63384197, 0.72424003, 0.90091723, 0.70822754,
#        0.78037011, 0.70563438, 0.66195275, 0.85516281, 0.6253688 ,
#        0.47930505, 0.68918504, 0.8377328 , 0.65204715, 0.86155791,
#        0.55876893, 0.89597087, 0.6165251 , 0.86834475, 0.63319919,
#        0.85963831, 0.54276806, 0.47467276, 0.55880677, 0.80691014,
#        0.7272126 , 0.56913353, 0.71963228, 0.63944322, 0.8581625 ,
#        0.70209361, 0.68028035, 0.65359225, 0.72756258, 1.00927291,
#        0.72246011, 0.62716701, 0.66901848, 0.9655925 , 0.67351202,
#        0.52637204, 0.64724032, 0.7887757 , 0.51898339, 0.49581575,
# ...

# %%
model.score(x_test, y_test)
# Out:
# 0.8163884002484665
